# %%
# %reload_ext tensorboard
import numpy as np
import tensorflow as tf
import csv
import pandas as pd
import datetime
import logging
from keras.callbacks import Callback
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score, classification_report
# from tensorflow.keras import backend as K
from keras_self_attention import SeqSelfAttention
import keras
import os
from imblearn.over_sampling import SMOTE, ADASYN
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# get TF logger
log = logging.getLogger('tensorflow')
log.setLevel(logging.DEBUG)

# create formatter and add it to the handlers
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')

# create file handler which logs even debug messages
fh = logging.FileHandler('tensorflow.log')
fh.setLevel(logging.DEBUG)
fh.setFormatter(formatter)
log.addHandler(fh)

tf.keras.backend.set_floatx('float64')

filenames = ['Friday-02-03-2018_TrafficForML_CICFlowMeter.csv', #0
             'Friday-16-02-2018_TrafficForML_CICFlowMeter.csv',
             'Friday-23-02-2018_TrafficForML_CICFlowMeter.csv',
             'Thursday-01-03-2018_TrafficForML_CICFlowMeter.csv',
             'Thursday-15-02-2018_TrafficForML_CICFlowMeter.csv',
             'Thursday-22-02-2018_TrafficForML_CICFlowMeter.csv',
             'Wednesday-14-02-2018_TrafficForML_CICFlowMeter.csv',
             'Wednesday-21-02-2018_TrafficForML_CICFlowMeter.csv',
             'Wednesday-28-02-2018_TrafficForML_CICFlowMeter.csv', #8
             'Thuesday-20-02-2018_TrafficForML_CICFlowMeter.csv'
            ]
def get_data(class_num=7):
    if class_num==7:
        li = []
        for filename in filenames:
            print(filename)
            df = pd.read_csv("7_classes/processed/%s"%filename, index_col=None)
            li.append(df)

        frame = pd.concat(li, axis=0, ignore_index=True)
        frame.pop("Unnamed: 0")
        return frame

def preprocess_data(frame, class_num=7, batch_size=128):
    train_li, validate_li, test_li = [], [], []
    for i in range(class_num):
        print(i)
        count = len(frame[frame['Label']==i])
        if count>2000000:
            count = 2000000
        train_count = int(0.7 * count)
        test_count = int(0.15 * count)
        validate_count = int(0.15 * count)
        train_li.append(frame[frame['Label']==i].sample(n=count,random_state=rnd_seed)[0:train_count])
        validate_li.append(frame[frame['Label']==i].sample(n=count,
                                                           random_state=rnd_seed)[train_count:train_count+validate_count])
        test_li.append(frame[frame['Label']==i].sample(n=count,random_state=rnd_seed)[train_count+validate_count:count])
    
    train_frame = pd.concat(train_li, axis=0, ignore_index=True)
    validate_frame = pd.concat(validate_li, axis=0, ignore_index=True)
    test_frame = pd.concat(test_li, axis=0, ignore_index=True)
    
    train_labels = train_frame.pop("Label")
    validate_labels = validate_frame.pop("Label")
    test_labels = test_frame.pop("Label")

    train_dataset = tf.data.Dataset.from_tensor_slices((train_frame.values.reshape([-1,78,1]), 
                                                        tf.keras.utils.to_categorical(train_labels, 
                                                                                      class_num))).batch(batch_size)
    test_dataset = tf.data.Dataset.from_tensor_slices((test_frame.values.reshape([-1,78,1]), 
                                                        tf.keras.utils.to_categorical(test_labels, 
                                                                                      class_num))).batch(batch_size)
    val_dataset = tf.data.Dataset.from_tensor_slices((validate_frame.values.reshape([-1,78,1]), 
                                                        tf.keras.utils.to_categorical(validate_labels, 
                                                                                      class_num))).batch(batch_size)
    return (train_dataset, val_dataset, test_dataset)

def load_tmp_dataset(sampling_parameters, class_num=7):
    train_frame = pd.read_csv("train.csv", index_col=None)
    train_frame = train_frame.sample(n=len(train_frame))
    log.info("train_frame loaded")
    validate_frame = pd.read_csv("val.csv", index_col=None)
    log.info("validate_frame loaded")
    test_frame = pd.read_csv("test.csv", index_col=None)
    log.info("test_frame loaded")
    
    train_labels = train_frame.pop("Label")
    validate_labels = validate_frame.pop("Label")
    test_labels = test_frame.pop("Label")
    
    train_frame.pop("Dst Port")
    validate_frame.pop("Dst Port")
    test_frame.pop("Dst Port")

    x = train_frame.values
    y = train_labels #tf.keras.utils.to_categorical(train_labels, class_num)
    
    
    oversample = SMOTE(sampling_strategy = sampling_parameters)
    train_x, train_y = oversample.fit_resample(x, y)
    train_x = train_x.reshape([-1,77,1])
    train_y = tf.keras.utils.to_categorical(train_y, class_num)
    
    
    test_x = test_frame.values.reshape([-1,77,1]) 
    test_y = tf.keras.utils.to_categorical(test_labels, class_num)
    
    val_x = validate_frame.values.reshape([-1,77,1])
    val_y = tf.keras.utils.to_categorical(validate_labels, class_num)
    log.info("dataset loaded")
    return (train_x, train_y, val_x, val_y, test_x, test_y)

def get_compiled_model(parameters, out_classes=7):
    tmp_loss='categorical_crossentropy'
    metrics=['categorical_accuracy',
#                  tf.keras.metrics.Recall(dtype='float32'),
#                  tf.keras.metrics.Precision(dtype='float32'),
#                  f1
            ]
    model = keras.Sequential([keras.layers.LSTM(parameters['lstm1'], input_shape=(77, 1), return_sequences=True),
                              keras.layers.LSTM(parameters['lstm2'], return_sequences=True, dropout=0.1),
                              SeqSelfAttention(attention_width=parameters['att'], 
                                               attention_activation='sigmoid',
                                               name='Attention'),
                              keras.layers.LSTM(parameters['lstm3'], dropout=0.1),
#                               keras.layers.Flatten(),
                              keras.layers.Dense(parameters['dense1'], activation='relu'),
                              keras.layers.Dense(parameters['dense2'], activation='relu'),
                              keras.layers.Dense(7, activation='softmax')
                                ])

    model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.00003),
                  loss=tmp_loss,
                  metrics=metrics
                 )
    return model
# Out:
# Using TensorFlow backend.

# %%
sampling_parameters = [{#0:0, # 1 400 000
                        #1:0, #   266 664
                        2:100000, #       649
                        #3:0, #   884 753
                        #4:0, #   458 010
                        #5:0, #   200333
                        #6:0  #   113 353
                       },
                       {#0:0,
                        #1:0,
                        2:150000,
                        #3:0,
                        #4:0,
                        #5:0,
                        #6:0
                       },
                       {#0:0,
                        #1:0,
                        2:200000,
                        #3:0,
                        #4:0,
                        #5:0,
                        #6:0
                       },
                       {#0:0,
                        #1:0,
                        2:250000,
                        #3:0,
                        #4:0,
                        #5:0,
                        #6:0
                       },
#                        {#0:0,
#                         1:500000,
#                         2:500000,
#                         #3:0,
#                         4:500000,
#                         5:500000,
#                         6:500000
#                        },
#                        {#0:0,
#                         #1:0,
#                         2:200000,
#                         #3:0,
#                         #4:0,
#                         #5:0,
#                         6:200000
#                        },
                      ]
DNN_parameters = [{'lstm1':256,
                   'lstm2':256,
                   'att':256,
                   'lstm3':128,
                   'dense1':100,
                   'dense2':80,
                  },
                  {'lstm1':128,
                   'lstm2':128,
                   'att':128,
                   'lstm3':92,
                   'dense1':80,
                   'dense2':80,
                  },
                  {'lstm1':64,#256,
                   'lstm2':64,#128,
                   'att':64,#128,
                   'lstm3':64,
                   'dense1':64,
                   'dense2':32,
                  },
#                   {'lstm1':256,
#                    'lstm2':256,
#                    'att':128,
#                    'lstm3':128,
#                    'dense1':128,
#                    'dense2':64,
#                   },
#                   {'lstm1':92,
#                    'lstm2':92,
#                    'att':92,
#                    'lstm3':64,
#                    'dense1':64,
#                    'dense2':32,
#                   }
                 ]

# %%
predictions = {}
for num1, samp_par in enumerate(sampling_parameters):
#     if num1==0 or num1==1:
#         continue
    for num2, net_par in enumerate(DNN_parameters):
        train_x, train_y, val_x, val_y, test_x, test_y = load_tmp_dataset(samp_par)
        model = get_compiled_model(net_par)
        log_dir=os.path.join('logs/long_fit_GRU/'+"s%s_n%s/"%(num1, num2))
        tensorboard_callback = keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1, profile_batch = 100000000)
        mcp_save = ModelCheckpoint('GRU_models/model_%s_%s.h5'%(num1, num2), save_best_only=True, monitor='val_loss', mode='min')
        train_history = model.fit(train_x,
                                  train_y,
                                  epochs=10,
                                  batch_size=512,
                                  validation_data=(val_x, val_y),
                                  callbacks=[tensorboard_callback, mcp_save]
                                 )
        model = keras.models.load_model('GRU_models/model_%s_%s.h5'%(num1, num2), custom_objects={'SeqSelfAttention':SeqSelfAttention})
#         model.evaluate(test_x, test_y, callbacks=[tensorboard_callback])
        predictions["GRU_results/s%s_n%s"%(num1, num2)] = model.predict(test_x)
        np.save("GRU_results/s%s_n%s.npy"%(num1, num2), predictions["GRU_results/s%s_n%s"%(num1, num2)])
        print('===============')
        print(confusion_matrix(test_y.argmax(axis=1), predictions["GRU_results/s%s_n%s"%(num1, num2)].argmax(axis=1)))
        print(classification_report(test_y.argmax(axis=1), predictions["GRU_results/s%s_n%s"%(num1, num2)].argmax(axis=1)))
        print(num1,num2)
        print('===============')
# Out:
# INFO:tensorflow:train_frame loaded
# INFO:tensorflow:validate_frame loaded
# INFO:tensorflow:test_frame loaded
# INFO:tensorflow:dataset loaded
# Train on 3423113 samples, validate on 712233 samples
# Epoch 1/10
# 3423113/3423113 [==============================] - 5411s 2ms/step - loss: 0.4046 - categorical_accuracy: 0.8653 - val_loss: 0.1958 - val_categorical_accuracy: 0.9360
# Epoch 2/10
# 3423113/3423113 [==============================] - 5400s 2ms/step - loss: 0.1934 - categorical_accuracy: 0.9357 - val_loss: 0.1714 - val_categorical_accuracy: 0.9436
# Epoch 3/10
# 3423113/3423113 [==============================] - 5411s 2ms/step - loss: 0.1698 - categorical_accuracy: 0.9426 - val_loss: 0.1608 - val_categorical_accuracy: 0.9457
# Epoch 4/10
# 3423113/3423113 [==============================] - 5408s 2ms/step - loss: 0.1616 - categorical_accuracy: 0.9446 - val_loss: 0.1560 - val_categorical_accuracy: 0.9463
# Epoch 5/10
# 3423113/3423113 [==============================] - 5408s 2ms/step - loss: 0.1575 - categorical_accuracy: 0.9456 - val_loss: 0.1556 - val_categorical_accuracy: 0.9463
# Epoch 6/10
# 3423113/3423113 [==============================] - 5402s 2ms/step - loss: 0.1546 - categorical_accuracy: 0.9463 - val_loss: 0.1524 - val_categorical_accuracy: 0.9467
# Epoch 7/10
# 3423113/3423113 [==============================] - 5412s 2ms/step - loss: 0.1523 - categorical_accuracy: 0.9468 - val_loss: 0.1480 - val_categorical_accuracy: 0.9478
# Epoch 8/10
# 3423113/3423113 [==============================] - 5410s 2ms/step - loss: 0.1502 - categorical_accuracy: 0.9472 - val_loss: 0.1465 - val_categorical_accuracy: 0.9482
# Epoch 9/10
# 3423113/3423113 [==============================] - 5406s 2ms/step - loss: 0.1490 - categorical_accuracy: 0.9475 - val_loss: 0.1458 - val_categorical_accuracy: 0.9481
# Epoch 10/10
# 3423113/3423113 [==============================] - 5400s 2ms/step - loss: 0.1481 - categorical_accuracy: 0.9477 - val_loss: 0.1438 - val_categorical_accuracy: 0.9488
# ===============
# [[297655     23    181    416    179    254   1292]
#  [     6  53438      0      0   3699      0      0]
#  [     5      0    131      0      0      4      0]
#  [   189      0      7 189394      0      1      0]
#  [    28  10264      0      0  87852      0      1]
#  [   181      0    215      1      0  42531      2]
#  [ 19170      3     25     62     10     28   4993]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96    300000
#            1       0.84      0.94      0.88     57143
#            2       0.23      0.94      0.37       140
#            3       1.00      1.00      1.00    189591
#            4       0.96      0.90      0.93     98145
#            5       0.99      0.99      0.99     42930
#            6       0.79      0.21      0.33     24291
#
#     accuracy                           0.95    712240
#    macro avg       0.82      0.85      0.78    712240
# weighted avg       0.95      0.95      0.94    712240
#
# 0 0
# ===============
# INFO:tensorflow:train_frame loaded
# INFO:tensorflow:validate_frame loaded
# INFO:tensorflow:test_frame loaded
# INFO:tensorflow:dataset loaded
# Train on 3423113 samples, validate on 712233 samples
# Epoch 1/10
# 3423113/3423113 [==============================] - 3685s 1ms/step - loss: 0.5179 - categorical_accuracy: 0.8274 - val_loss: 0.2138 - val_categorical_accuracy: 0.9327
# Epoch 2/10
# 3423113/3423113 [==============================] - 3684s 1ms/step - loss: 0.2196 - categorical_accuracy: 0.9287 - val_loss: 0.1861 - val_categorical_accuracy: 0.9390
# Epoch 3/10
# 3423113/3423113 [==============================] - 3687s 1ms/step - loss: 0.1931 - categorical_accuracy: 0.9353 - val_loss: 0.1724 - val_categorical_accuracy: 0.9434
# Epoch 4/10
# 3423113/3423113 [==============================] - 3685s 1ms/step - loss: 0.1794 - categorical_accuracy: 0.9392 - val_loss: 0.1643 - val_categorical_accuracy: 0.9458
# Epoch 5/10
# 3423113/3423113 [==============================] - 3686s 1ms/step - loss: 0.1722 - categorical_accuracy: 0.9414 - val_loss: 0.1667 - val_categorical_accuracy: 0.9432
# Epoch 6/10
# 3423113/3423113 [==============================] - 3687s 1ms/step - loss: 0.1675 - categorical_accuracy: 0.9429 - val_loss: 0.1605 - val_categorical_accuracy: 0.9454
# Epoch 7/10
# 3423113/3423113 [==============================] - 3683s 1ms/step - loss: 0.1644 - categorical_accuracy: 0.9438 - val_loss: 0.1586 - val_categorical_accuracy: 0.9460
# Epoch 8/10
# 3423113/3423113 [==============================] - 3682s 1ms/step - loss: 0.1620 - categorical_accuracy: 0.9445 - val_loss: 0.1575 - val_categorical_accuracy: 0.9463
# Epoch 9/10
# 3423113/3423113 [==============================] - 3682s 1ms/step - loss: 0.1605 - categorical_accuracy: 0.9449 - val_loss: 0.1561 - val_categorical_accuracy: 0.9467
# Epoch 10/10
# 3423113/3423113 [==============================] - 3682s 1ms/step - loss: 0.1588 - categorical_accuracy: 0.9455 - val_loss: 0.1532 - val_categorical_accuracy: 0.9475
# ===============
# [[297079     20    473    599    267    338   1224]
#  [    20  53566      1      0   3556      0      0]
#  [     7      0    128      0      0      5      0]
#  [   173      0     40 189378      0      0      0]
#  [    88  10153      1      0  87903      0      0]
#  [   160      0     76     16      0  42677      1]
#  [ 19561      3    184     79     20     44   4400]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96    300000
#            1       0.84      0.94      0.89     57143
#            2       0.14      0.91      0.25       140
#            3       1.00      1.00      1.00    189591
#            4       0.96      0.90      0.93     98145
#            5       0.99      0.99      0.99     42930
#            6       0.78      0.18      0.29     24291
#
#     accuracy                           0.95    712240
#    macro avg       0.81      0.84      0.76    712240
# weighted avg       0.95      0.95      0.94    712240
#
# 0 1
# ===============
# INFO:tensorflow:train_frame loaded
# INFO:tensorflow:validate_frame loaded
# INFO:tensorflow:test_frame loaded
# INFO:tensorflow:dataset loaded
# Train on 3423113 samples, validate on 712233 samples
# Epoch 1/10
# 3423113/3423113 [==============================] - 3205s 936us/step - loss: 0.7030 - categorical_accuracy: 0.7594 - val_loss: 0.2338 - val_categorical_accuracy: 0.9313
# Epoch 2/10
# 3423113/3423113 [==============================] - 3205s 936us/step - loss: 0.2368 - categorical_accuracy: 0.9246 - val_loss: 0.1967 - val_categorical_accuracy: 0.9360
# Epoch 3/10
# 3423113/3423113 [==============================] - 3205s 936us/step - loss: 0.2042 - categorical_accuracy: 0.9324 - val_loss: 0.1815 - val_categorical_accuracy: 0.9373
# Epoch 4/10
# 3423113/3423113 [==============================] - 3208s 937us/step - loss: 0.1905 - categorical_accuracy: 0.9360 - val_loss: 0.1750 - val_categorical_accuracy: 0.9419
# Epoch 5/10
# 3423113/3423113 [==============================] - 3205s 936us/step - loss: 0.1828 - categorical_accuracy: 0.9381 - val_loss: 0.1706 - val_categorical_accuracy: 0.9411
# Epoch 6/10
# 3423113/3423113 [==============================] - 3205s 936us/step - loss: 0.1776 - categorical_accuracy: 0.9400 - val_loss: 0.1673 - val_categorical_accuracy: 0.9433
# Epoch 7/10
# 3423113/3423113 [==============================] - 3203s 936us/step - loss: 0.1738 - categorical_accuracy: 0.9410 - val_loss: 0.1654 - val_categorical_accuracy: 0.9442
# Epoch 8/10
# 3423113/3423113 [==============================] - 3204s 936us/step - loss: 0.1708 - categorical_accuracy: 0.9419 - val_loss: 0.1624 - val_categorical_accuracy: 0.9444
# Epoch 9/10
# 3423113/3423113 [==============================] - 3203s 936us/step - loss: 0.1681 - categorical_accuracy: 0.9427 - val_loss: 0.1610 - val_categorical_accuracy: 0.9448
# Epoch 10/10
# 3423113/3423113 [==============================] - 3204s 936us/step - loss: 0.1659 - categorical_accuracy: 0.9433 - val_loss: 0.1601 - val_categorical_accuracy: 0.9450
# ===============
# [[296584     77    750    547    556    319   1167]
#  [     2  54413      0      0   2727      0      1]
#  [    12      0    123      0      0      5      0]
#  [   255      0    102 189234      0      0      0]
#  [   255  11922      1      2  85965      0      0]
#  [   235      0     71      3      6  42615      0]
#  [ 19538     14    215     71     90     30   4333]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96    300000
#            1       0.82      0.95      0.88     57143
#            2       0.10      0.88      0.18       140
#            3       1.00      1.00      1.00    189591
#            4       0.96      0.88      0.92     98145
#            5       0.99      0.99      0.99     42930
#            6       0.79      0.18      0.29     24291
#
#     accuracy                           0.95    712240
#    macro avg       0.80      0.84      0.75    712240
# weighted avg       0.94      0.95      0.94    712240
#
# 0 2
# ===============
# INFO:tensorflow:train_frame loaded
# INFO:tensorflow:validate_frame loaded
# INFO:tensorflow:test_frame loaded
# INFO:tensorflow:dataset loaded
# Train on 3473113 samples, validate on 712233 samples
# Epoch 1/10
# 3473113/3473113 [==============================] - 5512s 2ms/step - loss: 0.3967 - categorical_accuracy: 0.8653 - val_loss: 0.1861 - val_categorical_accuracy: 0.9395
# Epoch 2/10
# 3473113/3473113 [==============================] - 5517s 2ms/step - loss: 0.1797 - categorical_accuracy: 0.9393 - val_loss: 0.1642 - val_categorical_accuracy: 0.9459
# Epoch 3/10
# 3473113/3473113 [==============================] - 5511s 2ms/step - loss: 0.1641 - categorical_accuracy: 0.9438 - val_loss: 0.1611 - val_categorical_accuracy: 0.9453
# Epoch 4/10
# 3473113/3473113 [==============================] - 5513s 2ms/step - loss: 0.1577 - categorical_accuracy: 0.9454 - val_loss: 0.1552 - val_categorical_accuracy: 0.9468
# Epoch 5/10
# 3473113/3473113 [==============================] - 5506s 2ms/step - loss: 0.1540 - categorical_accuracy: 0.9465 - val_loss: 0.1517 - val_categorical_accuracy: 0.9425
# Epoch 6/10
# 3473113/3473113 [==============================] - 5512s 2ms/step - loss: 0.1521 - categorical_accuracy: 0.9472 - val_loss: 0.1492 - val_categorical_accuracy: 0.9483
# Epoch 7/10
# 3473113/3473113 [==============================] - 5510s 2ms/step - loss: 0.1512 - categorical_accuracy: 0.9474 - val_loss: 0.1511 - val_categorical_accuracy: 0.9474
# Epoch 8/10
# 3473113/3473113 [==============================] - 5509s 2ms/step - loss: 0.1498 - categorical_accuracy: 0.9477 - val_loss: 0.1541 - val_categorical_accuracy: 0.9466
# Epoch 9/10
# 3473113/3473113 [==============================] - 5504s 2ms/step - loss: 0.1485 - categorical_accuracy: 0.9479 - val_loss: 0.1486 - val_categorical_accuracy: 0.9479
# Epoch 10/10
# 3473113/3473113 [==============================] - 5511s 2ms/step - loss: 0.1474 - categorical_accuracy: 0.9480 - val_loss: 0.1460 - val_categorical_accuracy: 0.9492
# ===============
# [[297618     12    221    423    186    267   1273]
#  [     2  53573      0      0   3568      0      0]
#  [     5      0    131      0      0      4      0]
#  [   122      0    101 189366      0      2      0]
#  [    33  10156      0      0  87956      0      0]
#  [   155      0    204      1      0  42568      2]
#  [ 19132      9     18     56      8     27   5041]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96    300000
#            1       0.84      0.94      0.89     57143
#            2       0.19      0.94      0.32       140
#            3       1.00      1.00      1.00    189591
#            4       0.96      0.90      0.93     98145
#            5       0.99      0.99      0.99     42930
#            6       0.80      0.21      0.33     24291
#
#     accuracy                           0.95    712240
#    macro avg       0.82      0.85      0.77    712240
# weighted avg       0.95      0.95      0.94    712240
#
# 1 0
# ===============
# INFO:tensorflow:train_frame loaded
# INFO:tensorflow:validate_frame loaded
# INFO:tensorflow:test_frame loaded
# INFO:tensorflow:dataset loaded
# Train on 3473113 samples, validate on 712233 samples
# Epoch 1/10
# 3473113/3473113 [==============================] - 3779s 1ms/step - loss: 0.5640 - categorical_accuracy: 0.8103 - val_loss: 0.2395 - val_categorical_accuracy: 0.9216
# Epoch 2/10
# 3473113/3473113 [==============================] - 3774s 1ms/step - loss: 0.2223 - categorical_accuracy: 0.9272 - val_loss: 0.1800 - val_categorical_accuracy: 0.9410
# Epoch 3/10
# 3473113/3473113 [==============================] - 3780s 1ms/step - loss: 0.1845 - categorical_accuracy: 0.9385 - val_loss: 0.1663 - val_categorical_accuracy: 0.9455
# Epoch 4/10
# 3473113/3473113 [==============================] - 3778s 1ms/step - loss: 0.1728 - categorical_accuracy: 0.9422 - val_loss: 0.1630 - val_categorical_accuracy: 0.9461
# Epoch 5/10
# 3473113/3473113 [==============================] - 3779s 1ms/step - loss: 0.1663 - categorical_accuracy: 0.9440 - val_loss: 0.1577 - val_categorical_accuracy: 0.9471
# Epoch 6/10
# 3473113/3473113 [==============================] - 3778s 1ms/step - loss: 0.1622 - categorical_accuracy: 0.9450 - val_loss: 0.1558 - val_categorical_accuracy: 0.9468
# Epoch 7/10
# 3473113/3473113 [==============================] - 3778s 1ms/step - loss: 0.1595 - categorical_accuracy: 0.9455 - val_loss: 0.1558 - val_categorical_accuracy: 0.9468
# Epoch 8/10
# 3473113/3473113 [==============================] - 3790s 1ms/step - loss: 0.1576 - categorical_accuracy: 0.9460 - val_loss: 0.1535 - val_categorical_accuracy: 0.9473
# Epoch 9/10
# 3473113/3473113 [==============================] - 3778s 1ms/step - loss: 0.1564 - categorical_accuracy: 0.9462 - val_loss: 0.1521 - val_categorical_accuracy: 0.9481
# Epoch 10/10
# 3473113/3473113 [==============================] - 3775s 1ms/step - loss: 0.1550 - categorical_accuracy: 0.9466 - val_loss: 0.1504 - val_categorical_accuracy: 0.9482
# ===============
# [[297507     23    259    402    246    329   1234]
#  [    39  53651      2      0   3451      0      0]
#  [     5      0    131      0      0      4      0]
#  [   249      0     62 189264      1     15      0]
#  [    53  10308     14      0  87770      0      0]
#  [   157      0    126      1      4  42642      0]
#  [ 19507      2     51     66     11     40   4614]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96    300000
#            1       0.84      0.94      0.89     57143
#            2       0.20      0.94      0.33       140
#            3       1.00      1.00      1.00    189591
#            4       0.96      0.89      0.93     98145
#            5       0.99      0.99      0.99     42930
#            6       0.79      0.19      0.31     24291
#
#     accuracy                           0.95    712240
#    macro avg       0.82      0.85      0.77    712240
# weighted avg       0.95      0.95      0.94    712240
#
# 1 1
# ===============
# INFO:tensorflow:train_frame loaded
# INFO:tensorflow:validate_frame loaded
# INFO:tensorflow:test_frame loaded
# INFO:tensorflow:dataset loaded
# Train on 3473113 samples, validate on 712233 samples
# Epoch 1/10
# 3473113/3473113 [==============================] - 3276s 943us/step - loss: 0.6714 - categorical_accuracy: 0.7676 - val_loss: 0.2509 - val_categorical_accuracy: 0.9184
# Epoch 2/10
# 3473113/3473113 [==============================] - 3276s 943us/step - loss: 0.2346 - categorical_accuracy: 0.9240 - val_loss: 0.1919 - val_categorical_accuracy: 0.9356
# Epoch 3/10
# 3473113/3473113 [==============================] - 3274s 943us/step - loss: 0.1968 - categorical_accuracy: 0.9332 - val_loss: 0.1775 - val_categorical_accuracy: 0.9403
# Epoch 4/10
# 3473113/3473113 [==============================] - 3271s 942us/step - loss: 0.1836 - categorical_accuracy: 0.9375 - val_loss: 0.1703 - val_categorical_accuracy: 0.9435
# Epoch 5/10
# 3473113/3473113 [==============================] - 3274s 943us/step - loss: 0.1772 - categorical_accuracy: 0.9396 - val_loss: 0.1670 - val_categorical_accuracy: 0.9440
# Epoch 6/10
# 3473113/3473113 [==============================] - 3276s 943us/step - loss: 0.1731 - categorical_accuracy: 0.9405 - val_loss: 0.1649 - val_categorical_accuracy: 0.9419
# Epoch 7/10
# 3473113/3473113 [==============================] - 3276s 943us/step - loss: 0.1700 - categorical_accuracy: 0.9413 - val_loss: 0.1604 - val_categorical_accuracy: 0.9453
# Epoch 8/10
# 3473113/3473113 [==============================] - 3279s 944us/step - loss: 0.1673 - categorical_accuracy: 0.9421 - val_loss: 0.1591 - val_categorical_accuracy: 0.9452
# Epoch 9/10
# 3473113/3473113 [==============================] - 3285s 946us/step - loss: 0.1649 - categorical_accuracy: 0.9429 - val_loss: 0.1571 - val_categorical_accuracy: 0.9467
# Epoch 10/10
# 3473113/3473113 [==============================] - 3288s 947us/step - loss: 0.1628 - categorical_accuracy: 0.9436 - val_loss: 0.1553 - val_categorical_accuracy: 0.9466
# ===============
# [[297068     54    447    542    279    356   1254]
#  [     2  53830      0      0   3311      0      0]
#  [     9      0    127      0      0      4      0]
#  [   232      0    101 189258      0      0      0]
#  [   194  10926      0      1  87024      0      0]
#  [   156      1    138      1      0  42634      0]
#  [ 19425      6    176     77     27     36   4544]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96    300000
#            1       0.83      0.94      0.88     57143
#            2       0.13      0.91      0.22       140
#            3       1.00      1.00      1.00    189591
#            4       0.96      0.89      0.92     98145
#            5       0.99      0.99      0.99     42930
#            6       0.78      0.19      0.30     24291
#
#     accuracy                           0.95    712240
#    macro avg       0.80      0.84      0.75    712240
# weighted avg       0.95      0.95      0.94    712240
#
# 1 2
# ===============
# INFO:tensorflow:train_frame loaded
# INFO:tensorflow:validate_frame loaded
# INFO:tensorflow:test_frame loaded
# INFO:tensorflow:dataset loaded
# Train on 3523113 samples, validate on 712233 samples
# Epoch 1/10
# 3523113/3523113 [==============================] - 5609s 2ms/step - loss: 0.3682 - categorical_accuracy: 0.8757 - val_loss: 0.1782 - val_categorical_accuracy: 0.9408
# Epoch 2/10
# 3523113/3523113 [==============================] - 5619s 2ms/step - loss: 0.1733 - categorical_accuracy: 0.9404 - val_loss: 0.1636 - val_categorical_accuracy: 0.9410
# Epoch 3/10
# 3523113/3523113 [==============================] - 5618s 2ms/step - loss: 0.1626 - categorical_accuracy: 0.9435 - val_loss: 0.1589 - val_categorical_accuracy: 0.9407
# Epoch 4/10
# 3523113/3523113 [==============================] - 5618s 2ms/step - loss: 0.1573 - categorical_accuracy: 0.9452 - val_loss: 0.1534 - val_categorical_accuracy: 0.9472
# Epoch 5/10
# 3523113/3523113 [==============================] - 5615s 2ms/step - loss: 0.1570 - categorical_accuracy: 0.9454 - val_loss: 0.1588 - val_categorical_accuracy: 0.9456
# Epoch 6/10
# 3523113/3523113 [==============================] - 5617s 2ms/step - loss: 0.1518 - categorical_accuracy: 0.9470 - val_loss: 0.1505 - val_categorical_accuracy: 0.9480
# Epoch 7/10
# 3523113/3523113 [==============================] - 5623s 2ms/step - loss: 0.1498 - categorical_accuracy: 0.9475 - val_loss: 0.1554 - val_categorical_accuracy: 0.9457
# Epoch 8/10
# 3523113/3523113 [==============================] - 5615s 2ms/step - loss: 0.1488 - categorical_accuracy: 0.9476 - val_loss: 0.1507 - val_categorical_accuracy: 0.9479
# Epoch 9/10
# 3523113/3523113 [==============================] - 5614s 2ms/step - loss: 0.1475 - categorical_accuracy: 0.9478 - val_loss: 0.1466 - val_categorical_accuracy: 0.9485
# Epoch 10/10
# 3523113/3523113 [==============================] - 5617s 2ms/step - loss: 0.1461 - categorical_accuracy: 0.9482 - val_loss: 0.1447 - val_categorical_accuracy: 0.9493
# ===============
# [[297638      8    209    389    182    288   1286]
#  [     1  53953      2      0   3187      0      0]
#  [     5      0    131      0      0      4      0]
#  [   198      0     71 189321      1      0      0]
#  [    19  10472      0      0  87652      0      2]
#  [   114      0    168      2      0  42644      2]
#  [ 19132      3     15     58      4     30   5049]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96    300000
#            1       0.84      0.94      0.89     57143
#            2       0.22      0.94      0.36       140
#            3       1.00      1.00      1.00    189591
#            4       0.96      0.89      0.93     98145
#            5       0.99      0.99      0.99     42930
#            6       0.80      0.21      0.33     24291
#
#     accuracy                           0.95    712240
#    macro avg       0.82      0.85      0.78    712240
# weighted avg       0.95      0.95      0.94    712240
#
# 2 0
# ===============
# INFO:tensorflow:train_frame loaded
# INFO:tensorflow:validate_frame loaded
# INFO:tensorflow:test_frame loaded
# INFO:tensorflow:dataset loaded
# Train on 3523113 samples, validate on 712233 samples
# Epoch 1/10
# 3523113/3523113 [==============================] - 3903s 1ms/step - loss: 0.5162 - categorical_accuracy: 0.8248 - val_loss: 0.1955 - val_categorical_accuracy: 0.9358
# Epoch 2/10
# 3523113/3523113 [==============================] - 3894s 1ms/step - loss: 0.1933 - categorical_accuracy: 0.9357 - val_loss: 0.1769 - val_categorical_accuracy: 0.9410
# Epoch 3/10
# 3523113/3523113 [==============================] - 3899s 1ms/step - loss: 0.1749 - categorical_accuracy: 0.9408 - val_loss: 0.1663 - val_categorical_accuracy: 0.9431
# Epoch 4/10
# 3523113/3523113 [==============================] - 3894s 1ms/step - loss: 0.1661 - categorical_accuracy: 0.9433 - val_loss: 0.1588 - val_categorical_accuracy: 0.9466
# Epoch 5/10
# 3523113/3523113 [==============================] - 3890s 1ms/step - loss: 0.1602 - categorical_accuracy: 0.9450 - val_loss: 0.1569 - val_categorical_accuracy: 0.9470
# Epoch 6/10
# 3523113/3523113 [==============================] - 3891s 1ms/step - loss: 0.1575 - categorical_accuracy: 0.9459 - val_loss: 0.1732 - val_categorical_accuracy: 0.9439
# Epoch 7/10
# 3523113/3523113 [==============================] - 3892s 1ms/step - loss: 0.1557 - categorical_accuracy: 0.9463 - val_loss: 0.1532 - val_categorical_accuracy: 0.9480
# Epoch 8/10
# 3523113/3523113 [==============================] - 3894s 1ms/step - loss: 0.1542 - categorical_accuracy: 0.9467 - val_loss: 0.1546 - val_categorical_accuracy: 0.9469
# Epoch 9/10
# 3523113/3523113 [==============================] - 3896s 1ms/step - loss: 0.1532 - categorical_accuracy: 0.9468 - val_loss: 0.1544 - val_categorical_accuracy: 0.9469
# Epoch 10/10
# 3523113/3523113 [==============================] - 3895s 1ms/step - loss: 0.1520 - categorical_accuracy: 0.9471 - val_loss: 0.1525 - val_categorical_accuracy: 0.9475
# ===============
# [[296849     26    685    598    230    342   1270]
#  [     5  53313      1      0   3824      0      0]
#  [     5      0    131      0      0      4      0]
#  [   122      0    103 189363      0      2      1]
#  [    29  10183      0      1  87928      0      4]
#  [   109      0    192      1      3  42625      0]
#  [ 19028      4    202     73     17     41   4926]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96    300000
#            1       0.84      0.93      0.88     57143
#            2       0.10      0.94      0.18       140
#            3       1.00      1.00      1.00    189591
#            4       0.96      0.90      0.92     98145
#            5       0.99      0.99      0.99     42930
#            6       0.79      0.20      0.32     24291
#
#     accuracy                           0.95    712240
#    macro avg       0.80      0.85      0.75    712240
# weighted avg       0.95      0.95      0.94    712240
#
# 2 1
# ===============
# INFO:tensorflow:train_frame loaded
# INFO:tensorflow:validate_frame loaded
# INFO:tensorflow:test_frame loaded
# INFO:tensorflow:dataset loaded
# Train on 3523113 samples, validate on 712233 samples
# Epoch 1/10
# 3523113/3523113 [==============================] - 3390s 962us/step - loss: 0.6568 - categorical_accuracy: 0.7769 - val_loss: 0.2509 - val_categorical_accuracy: 0.9227
# Epoch 2/10
# 3523113/3523113 [==============================] - 3387s 961us/step - loss: 0.2482 - categorical_accuracy: 0.9221 - val_loss: 0.2143 - val_categorical_accuracy: 0.9321
# Epoch 3/10
# 3523113/3523113 [==============================] - 3386s 961us/step - loss: 0.2168 - categorical_accuracy: 0.9305 - val_loss: 0.1957 - val_categorical_accuracy: 0.9378
# Epoch 4/10
# 3523113/3523113 [==============================] - 3383s 960us/step - loss: 0.1986 - categorical_accuracy: 0.9353 - val_loss: 0.1809 - val_categorical_accuracy: 0.9418
# Epoch 5/10
# 3523113/3523113 [==============================] - 3386s 961us/step - loss: 0.1862 - categorical_accuracy: 0.9383 - val_loss: 0.1740 - val_categorical_accuracy: 0.9422
# Epoch 6/10
# 3523113/3523113 [==============================] - 3380s 959us/step - loss: 0.1789 - categorical_accuracy: 0.9398 - val_loss: 0.1695 - val_categorical_accuracy: 0.9430
# Epoch 7/10
# 3523113/3523113 [==============================] - 3377s 959us/step - loss: 0.1746 - categorical_accuracy: 0.9406 - val_loss: 0.1678 - val_categorical_accuracy: 0.9434
# Epoch 8/10
# 3523113/3523113 [==============================] - 3408s 967us/step - loss: 0.1717 - categorical_accuracy: 0.9418 - val_loss: 0.1681 - val_categorical_accuracy: 0.9427
# Epoch 9/10
# 3523113/3523113 [==============================] - 3364s 955us/step - loss: 0.1694 - categorical_accuracy: 0.9424 - val_loss: 0.1662 - val_categorical_accuracy: 0.9433
# Epoch 10/10
# 3523113/3523113 [==============================] - 3377s 958us/step - loss: 0.1674 - categorical_accuracy: 0.9429 - val_loss: 0.1656 - val_categorical_accuracy: 0.9435
# ===============
# [[295404     38   1293   1407    230    407   1221]
#  [    27  53637      0      0   3478      0      1]
#  [     7      0    128      0      0      5      0]
#  [   379      0    111 189100      0      1      0]
#  [   153  10887      2      7  87096      0      0]
#  [   166      0    139      3     13  42609      0]
#  [ 19636     12    241     68     24     42   4268]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96    300000
#            1       0.83      0.94      0.88     57143
#            2       0.07      0.91      0.12       140
#            3       0.99      1.00      0.99    189591
#            4       0.96      0.89      0.92     98145
#            5       0.99      0.99      0.99     42930
#            6       0.78      0.18      0.29     24291
#
#     accuracy                           0.94    712240
#    macro avg       0.79      0.84      0.74    712240
# weighted avg       0.94      0.94      0.94    712240
#
# 2 2
# ===============
# INFO:tensorflow:train_frame loaded
# INFO:tensorflow:validate_frame loaded
# INFO:tensorflow:test_frame loaded
# INFO:tensorflow:dataset loaded
# Train on 3573113 samples, validate on 712233 samples
# Epoch 1/10
# 3573113/3573113 [==============================] - 5722s 2ms/step - loss: 0.3576 - categorical_accuracy: 0.8787 - val_loss: 0.1750 - val_categorical_accuracy: 0.9432
# Epoch 2/10
# 3573113/3573113 [==============================] - 5709s 2ms/step - loss: 0.1692 - categorical_accuracy: 0.9416 - val_loss: 0.1603 - val_categorical_accuracy: 0.9408
# Epoch 3/10
# 3573113/3573113 [==============================] - 5726s 2ms/step - loss: 0.1589 - categorical_accuracy: 0.9444 - val_loss: 0.1565 - val_categorical_accuracy: 0.9476
# Epoch 4/10
# 3573113/3573113 [==============================] - 5720s 2ms/step - loss: 0.1542 - categorical_accuracy: 0.9456 - val_loss: 0.1527 - val_categorical_accuracy: 0.9467
# Epoch 5/10
# 3573113/3573113 [==============================] - 5717s 2ms/step - loss: 0.1522 - categorical_accuracy: 0.9459 - val_loss: 0.1519 - val_categorical_accuracy: 0.9474
# Epoch 6/10
# 3573113/3573113 [==============================] - 5711s 2ms/step - loss: 0.1512 - categorical_accuracy: 0.9462 - val_loss: 0.1530 - val_categorical_accuracy: 0.9470
# Epoch 7/10
# 3573113/3573113 [==============================] - 5722s 2ms/step - loss: 0.1493 - categorical_accuracy: 0.9469 - val_loss: 0.1480 - val_categorical_accuracy: 0.9482
# Epoch 8/10
# 3573113/3573113 [==============================] - 5715s 2ms/step - loss: 0.1473 - categorical_accuracy: 0.9476 - val_loss: 0.1503 - val_categorical_accuracy: 0.9476
# Epoch 9/10
# 3573113/3573113 [==============================] - 5720s 2ms/step - loss: 0.1460 - categorical_accuracy: 0.9479 - val_loss: 0.1491 - val_categorical_accuracy: 0.9483
# Epoch 10/10
# 3573113/3573113 [==============================] - 5715s 2ms/step - loss: 0.1449 - categorical_accuracy: 0.9482 - val_loss: 0.1454 - val_categorical_accuracy: 0.9491
# ===============
# [[297597     28    239    418    186    283   1249]
#  [     1  53720      1      0   3421      0      0]
#  [     5      0    130      0      0      5      0]
#  [   171      0     97 189323      0      0      0]
#  [    22  10328      0      0  87790      0      5]
#  [   100      0    120      1      0  42709      0]
#  [ 19157      3     16     63     13     33   5006]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96    300000
#            1       0.84      0.94      0.89     57143
#            2       0.22      0.93      0.35       140
#            3       1.00      1.00      1.00    189591
#            4       0.96      0.89      0.93     98145
#            5       0.99      0.99      0.99     42930
#            6       0.80      0.21      0.33     24291
#
#     accuracy                           0.95    712240
#    macro avg       0.82      0.85      0.78    712240
# weighted avg       0.95      0.95      0.94    712240
#
# 3 0
# ===============
# INFO:tensorflow:train_frame loaded
# INFO:tensorflow:validate_frame loaded
# INFO:tensorflow:test_frame loaded
# INFO:tensorflow:dataset loaded
# Train on 3573113 samples, validate on 712233 samples
# Epoch 1/10
# 3573113/3573113 [==============================] - 3989s 1ms/step - loss: 0.5480 - categorical_accuracy: 0.8168 - val_loss: 0.2391 - val_categorical_accuracy: 0.9216
# Epoch 2/10
# 3573113/3573113 [==============================] - 3984s 1ms/step - loss: 0.2150 - categorical_accuracy: 0.9290 - val_loss: 0.1828 - val_categorical_accuracy: 0.9394
# Epoch 3/10
# 3573113/3573113 [==============================] - 3989s 1ms/step - loss: 0.1828 - categorical_accuracy: 0.9388 - val_loss: 0.1717 - val_categorical_accuracy: 0.9426
# Epoch 4/10
# 3573113/3573113 [==============================] - 3996s 1ms/step - loss: 0.1725 - categorical_accuracy: 0.9419 - val_loss: 0.1690 - val_categorical_accuracy: 0.9416
# Epoch 5/10
# 3573113/3573113 [==============================] - 3990s 1ms/step - loss: 0.1672 - categorical_accuracy: 0.9434 - val_loss: 0.1611 - val_categorical_accuracy: 0.9464
# Epoch 6/10
# 3573113/3573113 [==============================] - 3989s 1ms/step - loss: 0.1630 - categorical_accuracy: 0.9446 - val_loss: 0.1883 - val_categorical_accuracy: 0.9372
# Epoch 7/10
# 3573113/3573113 [==============================] - 3995s 1ms/step - loss: 0.1610 - categorical_accuracy: 0.9451 - val_loss: 0.1575 - val_categorical_accuracy: 0.9471
# Epoch 8/10
# 3573113/3573113 [==============================] - 3995s 1ms/step - loss: 0.1584 - categorical_accuracy: 0.9457 - val_loss: 0.1561 - val_categorical_accuracy: 0.9471
# Epoch 9/10
# 3573113/3573113 [==============================] - 3994s 1ms/step - loss: 0.1565 - categorical_accuracy: 0.9462 - val_loss: 0.1551 - val_categorical_accuracy: 0.9466
# Epoch 10/10
# 3573113/3573113 [==============================] - 3993s 1ms/step - loss: 0.1555 - categorical_accuracy: 0.9464 - val_loss: 0.1571 - val_categorical_accuracy: 0.9462
# ===============
# [[296826     31    759    509    277    401   1197]
#  [    28  52949     10      0   4156      0      0]
#  [     4      0    131      0      0      5      0]
#  [   168      0     95 189323      0      5      0]
#  [   132   9968      0      3  88042      0      0]
#  [   130      0    109      2      1  42688      0]
#  [ 19527      5     86     76     26     42   4529]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96    300000
#            1       0.84      0.93      0.88     57143
#            2       0.11      0.94      0.20       140
#            3       1.00      1.00      1.00    189591
#            4       0.95      0.90      0.92     98145
#            5       0.99      0.99      0.99     42930
#            6       0.79      0.19      0.30     24291
#
#     accuracy                           0.95    712240
#    macro avg       0.80      0.85      0.75    712240
# weighted avg       0.95      0.95      0.94    712240
#
# 3 1
# ===============
# INFO:tensorflow:train_frame loaded
# INFO:tensorflow:validate_frame loaded
# INFO:tensorflow:test_frame loaded
# INFO:tensorflow:dataset loaded
# Train on 3573113 samples, validate on 712233 samples
# Epoch 1/10
# 3573113/3573113 [==============================] - 3584s 1ms/step - loss: 0.6977 - categorical_accuracy: 0.7580 - val_loss: 0.2825 - val_categorical_accuracy: 0.9138
# Epoch 2/10
# 3573113/3573113 [==============================] - 3592s 1ms/step - loss: 0.2650 - categorical_accuracy: 0.9162 - val_loss: 0.2173 - val_categorical_accuracy: 0.9326
# Epoch 3/10
# 3573113/3573113 [==============================] - 3581s 1ms/step - loss: 0.2226 - categorical_accuracy: 0.9264 - val_loss: 0.1965 - val_categorical_accuracy: 0.9365
# Epoch 4/10
# 3573113/3573113 [==============================] - 3589s 1ms/step - loss: 0.2026 - categorical_accuracy: 0.9314 - val_loss: 0.1871 - val_categorical_accuracy: 0.9381
# Epoch 5/10
# 3573113/3573113 [==============================] - 3571s 999us/step - loss: 0.1892 - categorical_accuracy: 0.9349 - val_loss: 0.1782 - val_categorical_accuracy: 0.9392
# Epoch 6/10
# 3573113/3573113 [==============================] - 3560s 996us/step - loss: 0.1803 - categorical_accuracy: 0.9381 - val_loss: 0.1739 - val_categorical_accuracy: 0.9413
# Epoch 7/10
# 3573113/3573113 [==============================] - 3581s 1ms/step - loss: 0.1751 - categorical_accuracy: 0.9396 - val_loss: 0.1689 - val_categorical_accuracy: 0.9430
# Epoch 8/10
# 3573113/3573113 [==============================] - 3598s 1ms/step - loss: 0.1715 - categorical_accuracy: 0.9407 - val_loss: 0.1673 - val_categorical_accuracy: 0.9431
# Epoch 9/10
# 3573113/3573113 [==============================] - 3571s 999us/step - loss: 0.1686 - categorical_accuracy: 0.9416 - val_loss: 0.1644 - val_categorical_accuracy: 0.9440
# Epoch 10/10
# 3573113/3573113 [==============================] - 3588s 1ms/step - loss: 0.1664 - categorical_accuracy: 0.9424 - val_loss: 0.1637 - val_categorical_accuracy: 0.9443
# ===============
# [[296120     71   1334    559    380    357   1179]
#  [     2  53797      0      0   3343      0      1]
#  [     6      0    129      0      0      5      0]
#  [   293      0    102 189195      0      1      0]
#  [   189  11372     12      5  86567      0      0]
#  [   184      0    161      0      0  42585      0]
#  [ 19468     17    239     74     49     41   4403]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96    300000
#            1       0.82      0.94      0.88     57143
#            2       0.07      0.92      0.12       140
#            3       1.00      1.00      1.00    189591
#            4       0.96      0.88      0.92     98145
#            5       0.99      0.99      0.99     42930
#            6       0.79      0.18      0.29     24291
#
#     accuracy                           0.94    712240
#    macro avg       0.79      0.84      0.74    712240
# weighted avg       0.94      0.94      0.94    712240
#
# 3 2
# ===============

# %%
target_names = ['Benign', 'bruteforce', 'Web', 'DDOS', 'dos', 'Bot', 'Infilteration']
for name,pred in predictions.items():
    print("-----------%s---------------"%name)
    print('Confusion Matrix')
    print(confusion_matrix(test_y.argmax(axis=1), pred.argmax(axis=1)))
    print('Classification Report')
    print(classification_report(test_y.argmax(axis=1), pred.argmax(axis=1), target_names=target_names))
# Out:
# -----------s0_n0---------------
# Confusion Matrix
# [[297702      9    142    408    154    201   1384]
#  [     0  53746      1      0   3396      0      0]
#  [     5      0    131      0      0      4      0]
#  [    82      0     10 189499      0      0      0]
#  [    15  10178      0      0  87952      0      0]
#  [   137      0    203      1      0  42589      0]
#  [ 18789      3      5     59      1     15   5419]]
# Classification Report
#                precision    recall  f1-score   support
#
#        Benign       0.94      0.99      0.97    300000
#    bruteforce       0.84      0.94      0.89     57143
#           Web       0.27      0.94      0.41       140
#          DDOS       1.00      1.00      1.00    189591
#           dos       0.96      0.90      0.93     98145
#           Bot       0.99      0.99      0.99     42930
# Infilteration       0.80      0.22      0.35     24291
#
#      accuracy                           0.95    712240
#     macro avg       0.83      0.85      0.79    712240
#  weighted avg       0.95      0.95      0.94    712240
#
# -----------s0_n1---------------
# Confusion Matrix
# [[297604     20    163    361    175    261   1416]
#  [     1  53946      0      0   3196      0      0]
#  [     5      0    130      0      0      5      0]
#  [   158      0     51 189381      0      0      1]
#  [    32  10399      0      0  87709      0      5]
#  [    89      0    172      1      0  42667      1]
#  [ 18857      5      7     52      3     20   5347]]
# Classification Report
#                precision    recall  f1-score   support
#
#        Benign       0.94      0.99      0.97    300000
#    bruteforce       0.84      0.94      0.89     57143
#           Web       0.25      0.93      0.39       140
#          DDOS       1.00      1.00      1.00    189591
#           dos       0.96      0.89      0.93     98145
#           Bot       0.99      0.99      0.99     42930
# Infilteration       0.79      0.22      0.34     24291
#
#      accuracy                           0.95    712240
#     macro avg       0.82      0.85      0.79    712240
#  weighted avg       0.95      0.95      0.94    712240
#
# -----------s0_n2---------------
# Confusion Matrix
# [[297662     13    139    414    162    281   1329]
#  [     0  53871      1      0   3271      0      0]
#  [     5      0    131      0      0      4      0]
#  [   119      0     17 189455      0      0      0]
#  [    20  10377      0      0  87748      0      0]
#  [    60      0    156      1      0  42712      1]
#  [ 18873      4      6     53      1     23   5331]]
# Classification Report
#                precision    recall  f1-score   support
#
#        Benign       0.94      0.99      0.97    300000
#    bruteforce       0.84      0.94      0.89     57143
#           Web       0.29      0.94      0.44       140
#          DDOS       1.00      1.00      1.00    189591
#           dos       0.96      0.89      0.93     98145
#           Bot       0.99      0.99      0.99     42930
# Infilteration       0.80      0.22      0.34     24291
#
#      accuracy                           0.95    712240
#     macro avg       0.83      0.85      0.79    712240
#  weighted avg       0.95      0.95      0.94    712240
#
# -----------s0_n3---------------
# Confusion Matrix
# [[296705      5    854    545    158    330   1403]
#  [     2  53744      0      0   3397      0      0]
#  [     5      0    130      0      0      5      0]
#  [    91      0     16 189484      0      0      0]
#  [    16  10133      0      0  87994      0      2]
#  [    18      0     86      1      0  42825      0]
#  [ 18521      3    210     71      1     34   5451]]
# Classification Report
#                precision    recall  f1-score   support
#
#        Benign       0.94      0.99      0.96    300000
#    bruteforce       0.84      0.94      0.89     57143
#           Web       0.10      0.93      0.18       140
#          DDOS       1.00      1.00      1.00    189591
#           dos       0.96      0.90      0.93     98145
#           Bot       0.99      1.00      0.99     42930
# Infilteration       0.80      0.22      0.35     24291
#
#      accuracy                           0.95    712240
#     macro avg       0.80      0.85      0.76    712240
#  weighted avg       0.95      0.95      0.94    712240
#
# -----------s0_n4---------------
# Confusion Matrix
# [[297236      5    490    469    171    319   1310]
#  [    82  53382      1      0   3671      0      7]
#  [     5      0    130      0      0      5      0]
#  [   195      0    109 189286      1      0      0]
#  [    32  10265      0      0  87847      1      0]
#  [    71      0     35      1      0  42822      1]
#  [ 18788      1    178     62      3     32   5227]]
# Classification Report
#                precision    recall  f1-score   support
#
#        Benign       0.94      0.99      0.96    300000
#    bruteforce       0.84      0.93      0.88     57143
#           Web       0.14      0.93      0.24       140
#          DDOS       1.00      1.00      1.00    189591
#           dos       0.96      0.90      0.93     98145
#           Bot       0.99      1.00      0.99     42930
# Infilteration       0.80      0.22      0.34     24291
#
#      accuracy                           0.95    712240
#     macro avg       0.81      0.85      0.76    712240
#  weighted avg       0.95      0.95      0.94    712240
#
# -----------s1_n0---------------
# Confusion Matrix
# [[297882      2    135    395    157     68   1361]
#  [     1  53683      0      0   3459      0      0]
#  [     6      0    130      0      0      4      0]
#  [   105      0     93 189392      1      0      0]
#  [    19  10078      0      0  88048      0      0]
#  [  1178      0    140      1      0  41611      0]
#  [ 18802      2      4     55      1      8   5419]]
# Classification Report
#                precision    recall  f1-score   support
#
#        Benign       0.94      0.99      0.96    300000
#    bruteforce       0.84      0.94      0.89     57143
#           Web       0.26      0.93      0.40       140
#          DDOS       1.00      1.00      1.00    189591
#           dos       0.96      0.90      0.93     98145
#           Bot       1.00      0.97      0.98     42930
# Infilteration       0.80      0.22      0.35     24291
#
#      accuracy                           0.95    712240
#     macro avg       0.83      0.85      0.79    712240
#  weighted avg       0.95      0.95      0.94    712240
#
# -----------s1_n1---------------
# Confusion Matrix
# [[297608      6    173    406    167    307   1333]
#  [     1  54035      1      0   3106      0      0]
#  [     5      0    130      0      0      5      0]
#  [   113      0     29 189449      0      0      0]
#  [    18  10482      0      0  87645      0      0]
#  [    29      0    142      1      0  42758      0]
#  [ 18860      5     16     68      2     26   5314]]
# Classification Report
#                precision    recall  f1-score   support
#
#        Benign       0.94      0.99      0.97    300000
#    bruteforce       0.84      0.95      0.89     57143
#           Web       0.26      0.93      0.41       140
#          DDOS       1.00      1.00      1.00    189591
#           dos       0.96      0.89      0.93     98145
#           Bot       0.99      1.00      0.99     42930
# Infilteration       0.80      0.22      0.34     24291
#
#      accuracy                           0.95    712240
#     macro avg       0.83      0.85      0.79    712240
#  weighted avg       0.95      0.95      0.94    712240
#
# -----------s1_n2---------------
# Confusion Matrix
# [[297490      7    196    552    163    251   1341]
#  [     1  53949      1      0   3192      0      0]
#  [     5      0    131      0      0      4      0]
#  [   114      0     10 189467      0      0      0]
#  [    19  10294      0      0  87832      0      0]
#  [   100      0    160      1      0  42669      0]
#  [ 18807      3     39     73      1     25   5343]]
# Classification Report
#                precision    recall  f1-score   support
#
#        Benign       0.94      0.99      0.97    300000
#    bruteforce       0.84      0.94      0.89     57143
#           Web       0.24      0.94      0.39       140
#          DDOS       1.00      1.00      1.00    189591
#           dos       0.96      0.89      0.93     98145
#           Bot       0.99      0.99      0.99     42930
# Infilteration       0.80      0.22      0.34     24291
#
#      accuracy                           0.95    712240
#     macro avg       0.83      0.85      0.79    712240
#  weighted avg       0.95      0.95      0.94    712240
#
# -----------s1_n3---------------
# Confusion Matrix
# [[297348      5    239    479    140    259   1530]
#  [     1  53414      1      0   3726      0      1]
#  [     5      0    131      0      0      4      0]
#  [   157      0     98 189335      1      0      0]
#  [    17   9938      0      0  88190      0      0]
#  [    45      0    124      1      0  42760      0]
#  [ 18602      3     78     65      1     26   5516]]
# Classification Report
#                precision    recall  f1-score   support
#
#        Benign       0.94      0.99      0.97    300000
#    bruteforce       0.84      0.93      0.89     57143
#           Web       0.20      0.94      0.32       140
#          DDOS       1.00      1.00      1.00    189591
#           dos       0.96      0.90      0.93     98145
#           Bot       0.99      1.00      0.99     42930
# Infilteration       0.78      0.23      0.35     24291
#
#      accuracy                           0.95    712240
#     macro avg       0.82      0.85      0.78    712240
#  weighted avg       0.95      0.95      0.94    712240
#
# -----------s1_n4---------------
# Confusion Matrix
# [[297558      9    188    399    164    353   1329]
#  [    12  53875      1      0   3255      0      0]
#  [     6      0    129      0      0      5      0]
#  [   218      0     81 189290      0      0      2]
#  [    25  10389      0      0  87728      0      3]
#  [    35      0     77      1      0  42817      0]
#  [ 18981      2     17     59      5     34   5193]]
# Classification Report
#                precision    recall  f1-score   support
#
#        Benign       0.94      0.99      0.96    300000
#    bruteforce       0.84      0.94      0.89     57143
#           Web       0.26      0.92      0.41       140
#          DDOS       1.00      1.00      1.00    189591
#           dos       0.96      0.89      0.93     98145
#           Bot       0.99      1.00      0.99     42930
# Infilteration       0.80      0.21      0.34     24291
#
#      accuracy                           0.95    712240
#     macro avg       0.83      0.85      0.79    712240
#  weighted avg       0.95      0.95      0.94    712240

# %%
for name,pred in predictions.items():
    np.save('%s.npy'%name, pred)

# %%
# sampling_parameters[0] DNN_parameters[0]

# import tensorflow as tf
tf.debugging.set_log_device_placement(True)
# strategy = tf.distribute.MirroredStrategy()
# # with strategy.scope():
model = get_compiled_model(DNN_parameters[0])
#     log_dir=os.path.join('logs/long_fit/'+"testtt/")
#     tensorboard_callback = keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1, profile_batch = 100000000)
#     train_history = model.fit(train_x,
#                               train_y,
#                               epochs=20,
#                               batch_size=512,
#                               validation_data=(val_x, val_y),
#                               callbacks=[tensorboard_callback]
#                              )
# Out:
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Sub in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Add in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op LogicalNot in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Assert in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op ConcatV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op TruncatedNormal in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op TruncatedNormal in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op TruncatedNormal in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Reshape in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomUniform in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:GPU:0
